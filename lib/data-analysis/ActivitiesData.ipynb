# %%
import os
import numpy as np
import pandas as pd

# %%
# Data to DF
Activities = pd.read_csv("../data/cultural-spaces.csv", sep = ";").drop(["YEAR", "ACTIVE_SPACE","NUMBER_OF_SEATS","SQUARE_FEET"], axis=1)
Activities.columns = ["name", "website", "type", "use", "address", "area", "ownership", "Geom", "geo_point_2d"]
Activities
# Out:
#                                            name  \
# 0                                  AHVA Gallery
# 1                     Beaty Biodiversity Museum
# 2                         Douglas Udell Gallery
# 3                            Federation Gallery
# 4                              Granville Island
# ..                                          ...
# 704                             Ceperley Meadow
# 705                         Chali-Rosso Gallery
# 706        Vancouver Holocaust Education Centre
# 707  Coastal Peoples Fine Arts Gallery Yaletown
# 708                 H.R. Macmillan Space Centre
#
#                                   website             type  \
# 0       http://gallery.ahva.ubc.ca/about/   Museum/Gallery
# 1     http://www.beatymuseum.ubc.ca/about   Museum/Gallery
# 2            www.douglasudellgallery.com?   Museum/Gallery
# 3    http://artists.ca/federation_gallery   Museum/Gallery
# 4                                     NaN  Community Space
# ..                                    ...              ...
# 704                                   NaN  Community Space
# 705                    www.chalirosso.com   Museum/Gallery
# 706                         www.vhec.org?   Museum/Gallery
# 707         http://www.coastalpeoples.com   Museum/Gallery
# 708            http://www.spacecentre.ca/   Museum/Gallery
#
#                                 use  \
# 0                    Museum/Gallery
# 1                    Museum/Gallery
# 2                    Museum/Gallery
# 3                    Museum/Gallery
# 4             Plaza/Park/Band Shell
# ..                              ...
# 704           Plaza/Park/Band Shell
# 705                  Museum/Gallery
# 706                  Museum/Gallery
# 707                  Museum/Gallery
# 708  Garden/Aquarium/Science Centre
#
#                                         address          area  \
# 0          6398 University Blvd, Vancouver, BC,           UBC
# 1        2212 Main Mall, Vancouver, BC, V6T 1Z4           UBC
# 2         1558 W 6th Av, Vancouver, BC, V6J 1R2      Fairview
# 3    1241 Cartwright St, Vancouver, BC, V6H 4B7      Fairview
# 4               Granville Island, Vancouver, BC      Fairview
# ..                                          ...           ...
# 704                 Stanley Park, Vancouver, BC  Stanley Park
# 705   2250 Granville St, Vancouver, BC, V6H 4H7      Fairview
# 706       950 W 41st Av, Vancouver, BC, V5Z 2N7      Oakridge
# 707    1024 Mainland St, Vancouver, BC, V6B 2T4      Downtown
# 708    1100 Chestnut St, Vancouver, BC, V6J 3J9     Kitsilano
#
#              ownership                                               Geom  \
# 0                Other  {"coordinates": [-123.2549451, 49.2639124], "t...
# 1                Other  {"coordinates": [-123.251485, 49.2634318], "ty...
# 2      Privately Owned  {"coordinates": [-123.1399725, 49.2661804], "t...
# 3      Privately Owned  {"coordinates": [-123.13225, 49.269582], "type...
# 4           Government  {"coordinates": [-123.134845, 49.269463], "typ...
# ..                 ...                                                ...
# 704  City of Vancouver  {"coordinates": [-123.148518, 49.293772], "typ...
# 705    Privately Owned  {"coordinates": [-123.1384021, 49.2657529], "t...
# 706    Privately Owned  {"coordinates": [-123.126013, 49.233442], "typ...
# 707    Privately Owned  {"coordinates": [-123.119591, 49.2762084], "ty...
# 708  City of Vancouver  {"coordinates": [-123.144299, 49.276361], "typ...
#
#                  geo_point_2d
# 0    49.2639124, -123.2549451
# 1     49.2634318, -123.251485
# 2    49.2661804, -123.1399725
# 3       49.269582, -123.13225
# 4      49.269463, -123.134845
# ..                        ...
# 704    49.293772, -123.148518
# 705  49.2657529, -123.1384021
# 706    49.233442, -123.126013
# 707   49.2762084, -123.119591
# 708    49.276361, -123.144299
#
# [709 rows x 9 columns]

# %%
Activities[['latitude', 'longitude']] = Activities['geo_point_2d'].str.split(',', expand=True)
Activities['latitude'] = pd.to_numeric(Activities['latitude'])
Activities['longitude'] = pd.to_numeric(Activities['longitude'])
Activities
# Out:
#                                            name  \
# 0                                  AHVA Gallery
# 1                     Beaty Biodiversity Museum
# 2                         Douglas Udell Gallery
# 3                            Federation Gallery
# 4                              Granville Island
# ..                                          ...
# 704                             Ceperley Meadow
# 705                         Chali-Rosso Gallery
# 706        Vancouver Holocaust Education Centre
# 707  Coastal Peoples Fine Arts Gallery Yaletown
# 708                 H.R. Macmillan Space Centre
#
#                                   website             type  \
# 0       http://gallery.ahva.ubc.ca/about/   Museum/Gallery
# 1     http://www.beatymuseum.ubc.ca/about   Museum/Gallery
# 2            www.douglasudellgallery.com?   Museum/Gallery
# 3    http://artists.ca/federation_gallery   Museum/Gallery
# 4                                     NaN  Community Space
# ..                                    ...              ...
# 704                                   NaN  Community Space
# 705                    www.chalirosso.com   Museum/Gallery
# 706                         www.vhec.org?   Museum/Gallery
# 707         http://www.coastalpeoples.com   Museum/Gallery
# 708            http://www.spacecentre.ca/   Museum/Gallery
#
#                                 use  \
# 0                    Museum/Gallery
# 1                    Museum/Gallery
# 2                    Museum/Gallery
# 3                    Museum/Gallery
# 4             Plaza/Park/Band Shell
# ..                              ...
# 704           Plaza/Park/Band Shell
# 705                  Museum/Gallery
# 706                  Museum/Gallery
# 707                  Museum/Gallery
# 708  Garden/Aquarium/Science Centre
#
#                                         address          area  \
# 0          6398 University Blvd, Vancouver, BC,           UBC
# 1        2212 Main Mall, Vancouver, BC, V6T 1Z4           UBC
# 2         1558 W 6th Av, Vancouver, BC, V6J 1R2      Fairview
# 3    1241 Cartwright St, Vancouver, BC, V6H 4B7      Fairview
# 4               Granville Island, Vancouver, BC      Fairview
# ..                                          ...           ...
# 704                 Stanley Park, Vancouver, BC  Stanley Park
# 705   2250 Granville St, Vancouver, BC, V6H 4H7      Fairview
# 706       950 W 41st Av, Vancouver, BC, V5Z 2N7      Oakridge
# 707    1024 Mainland St, Vancouver, BC, V6B 2T4      Downtown
# 708    1100 Chestnut St, Vancouver, BC, V6J 3J9     Kitsilano
#
#              ownership                                               Geom  \
# 0                Other  {"coordinates": [-123.2549451, 49.2639124], "t...
# 1                Other  {"coordinates": [-123.251485, 49.2634318], "ty...
# 2      Privately Owned  {"coordinates": [-123.1399725, 49.2661804], "t...
# 3      Privately Owned  {"coordinates": [-123.13225, 49.269582], "type...
# 4           Government  {"coordinates": [-123.134845, 49.269463], "typ...
# ..                 ...                                                ...
# 704  City of Vancouver  {"coordinates": [-123.148518, 49.293772], "typ...
# 705    Privately Owned  {"coordinates": [-123.1384021, 49.2657529], "t...
# 706    Privately Owned  {"coordinates": [-123.126013, 49.233442], "typ...
# 707    Privately Owned  {"coordinates": [-123.119591, 49.2762084], "ty...
# 708  City of Vancouver  {"coordinates": [-123.144299, 49.276361], "typ...
#
#                  geo_point_2d   latitude   longitude
# 0    49.2639124, -123.2549451  49.263912 -123.254945
# 1     49.2634318, -123.251485  49.263432 -123.251485
# 2    49.2661804, -123.1399725  49.266180 -123.139972
# 3       49.269582, -123.13225  49.269582 -123.132250
# 4      49.269463, -123.134845  49.269463 -123.134845
# ..                        ...        ...         ...
# 704    49.293772, -123.148518  49.293772 -123.148518
# 705  49.2657529, -123.1384021  49.265753 -123.138402
# 706    49.233442, -123.126013  49.233442 -123.126013
# 707   49.2762084, -123.119591  49.276208 -123.119591
# 708    49.276361, -123.144299  49.276361 -123.144299
#
# [709 rows x 11 columns]

# %%
# Make sure the folder exists
os.makedirs("../cleaned", exist_ok=True)

# Export the DataFrame to CSV
Activities.to_csv("../cleaned/VancouverActivities.csv", index=False, encoding='utf-8')
print("exported Vancouver Restaurant data to cleaned/VancouverActivities.csv")
# Out:
# exported Vancouver Restaurant data to cleaned/VancouverActivities.csv
